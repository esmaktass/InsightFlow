# %% [markdown]
# # InsightFlow — Data Cleaning
#
# This notebook performs data quality assessment, cleaning, and basic feature engineering on the UCI Online Retail II dataset.
#
# ## Dataset
#
# Source: UCI Machine Learning Repository — Online Retail II
#
# The dataset contains transactional records from a UK-based online retailer between December 2009 and December 2011.

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
PROJECT_ROOT = Path.cwd().parent

RAW_DATA_PATH = PROJECT_ROOT / "data" / "raw" / "online_retail_II.xlsx"
PROCESSED_DATA_PATH = PROJECT_ROOT / "data" / "processed"

# %%
RAW_DATA_PATH.exists()
# Out:
# False

# %%
from pathlib import Path

print("Current working directory:")
print(Path.cwd())

print("\nProject root:")
print(Path.cwd().parent)

print("\nExpected raw path:")
print(Path.cwd().parent / "data" / "raw")

print("\nFiles inside raw folder:")
raw_folder = Path.cwd().parent / "data" / "raw"
print(list(raw_folder.iterdir()) if raw_folder.exists() else "raw folder does not exist")
# Out:
# Current working directory:
# c:\Users\esmak\InsightFlow\notebooks\notebooks
#
# Project root:
# c:\Users\esmak\InsightFlow\notebooks
#
# Expected raw path:
# c:\Users\esmak\InsightFlow\notebooks\data\raw
#
# Files inside raw folder:
# raw folder does not exist
